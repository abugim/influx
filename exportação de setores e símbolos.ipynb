# %%
library(TTR)

stockSymbols <- stockSymbols("NASDAQ")
# Out:
# Fetching NASDAQ symbols...

# %%
? write.csv

# %%
stockSymbols[,c('Symbol', 'Sector')]
write.csv(stockSymbols[,c('Sector', 'Symbol')], na = "",row.names = FALSE, file = "sector_symbol.csv")
# Out:
#      Symbol Sector
# 1    AAAP   Health Care
# 2    AAL    Transportation
# 3    AAME   Finance
# 4    AAOI   Technology
# 5    AAON   Capital Goods
# 6    AAPC   Consumer Services
# 7    AAPL   Technology
# 8    AAWW   Transportation
# 9    AAXJ   NA
# 10   AAXN   Capital Goods
# 11   ABAC   Consumer Non-Durables
# 12   ABAX   Capital Goods
# 13   ABCB   Finance
# 14   ABCD   Consumer Services
# 15   ABCO   Consumer Services
# 16   ABDC   NA
# 17   ABEO   Health Care
# 18   ABEOW  Health Care
# 19   ABIL   Finance
# 20   ABIO   Health Care
# 21   ABMD   Health Care
# 22   ABTL   Technology
# 23   ABTX   Finance
# 24   ABUS   Health Care
# 25   ABY    Public Utilities
# 26   ACAD   Health Care
# 27   ACBI   Finance
# 28   ACET   Health Care
# 29   ACFC   Finance
# 30   ACGL   Finance
# ⋮    ⋮      ⋮
# 3173 YIN    Finance
# 3174 YLCO   NA
# 3175 YLDE   NA
# 3176 YNDX   Technology
# 3177 YORW   Public Utilities
# 3178 YRCW   Transportation
# 3179 YTEN   Basic Industries
# ...

# %%
unique(stockSymbols["Sector"])
# Out:
#     Sector
# 1   Health Care
# 2   Transportation
# 3   Finance
# 4   Technology
# 5   Capital Goods
# 6   Consumer Services
# 9   NA
# 11  Consumer Non-Durables
# 25  Public Utilities
# 45  Miscellaneous
# 52  Basic Industries
# 76  Energy
# 160 Consumer Durables
