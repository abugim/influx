# %%
library(TTR)

# %%
df_symbols_amex <- stockSymbols('AMEX')
df_symbols_nasdaq <- stockSymbols('NASDAQ')
df_symbols_nyse <- stockSymbols('NYSE')
# Out:
# Fetching AMEX symbols...
# Fetching NASDAQ symbols...
# Fetching NYSE symbols...

# %%
stockSymbols <- x;
stockSymbols[,c('Symbol', 'Sector')]
write.csv(stockSymbols[,c('Sector', 'Symbol')], na = "",row.names = FALSE, file = "sector_symbol_AMEX.csv")

stockSymbols <- z;
stockSymbols[,c('Symbol', 'Sector')]
write.csv(stockSymbols[,c('Sector', 'Symbol')], na = "",row.names = FALSE, file = "sector_symbol_NYSE.csv")
# Out:
#     Symbol Sector
# 1   AAMC   Finance
# 2   AAU    Basic Industries
# 3   ABE    NA
# 4   ACU    Capital Goods
# 5   ACY    Technology
# 6   ADK    Health Care
# 7   ADK-PA NA
# 8   AE     Energy
# 9   AIII   Consumer Services
# 10  AINC   Consumer Services
# 11  AIRI   Capital Goods
# 12  AKG    Basic Industries
# 13  ALN    Consumer Non-Durables
# 14  ALO    Basic Industries
# 15  AMPE   Health Care
# 16  AMS    Health Care
# 17  APHB   Health Care
# 18  APT    Health Care
# 19  ARNC-P NA
# 20  ASM    Basic Industries
# 21  AST    Health Care
# 22  ATEST  NA
# 23  ATNM   Health Care
# 24  AUMN   Basic Industries
# 25  AUXO   Miscellaneous
# 26  AWX    Public Utilities
# 27  AXN    Health Care
# 28  AXU    Basic Industries
# 29  BAA    Basic Industries
# 30  BCV    NA
# ⋮   ⋮      ⋮
# 314 TXMD   Health Care
# 315 UAMY   Capital Goods
# 316 UEC    Basic Industries
# 317 UFAB   Capital Goods
# 318 UQM    Capital Goods
# 319 URG    Basic Industries
# 320 USAS   Basic Industries
# ...

# %%
# Out:
# Warning message in file(file, "rt"):
# “"internal" method cannot handle https redirection to: 'https://ichart.finance.yahoo.com/table.csv?s=IBM&a=0&b=1&c=2016&d=5&e=19&f=2017&g=d&ignore=.csv'”Warning message in file(file, "rt"):
# “"internal" method failed, so trying "libcurl"”Warning message in file(file, "rt"):
# “URL 'https://ichart.finance.yahoo.com/table.csv?s=IBM&a=0&b=1&c=2016&d=5&e=19&f=2017&g=d&ignore=.csv': status was '404 Not Found'”
# Error in file(file, "rt"): cannot open connection
# Traceback:
#
# 1. getYahooData("IBM", 20160101, 20161231)
# 2. getYahooData(symbol, start, freq = "daily", type = "price", adjust = FALSE,
#  .     quiet = TRUE)
# 3. read.table(url, header = TRUE, sep = ",")
# 4. file(file, "rt")
